# %%
import folium as geo
import pandas as pd
#import geocoder

#데이터 나눔은 액셀 수작업으로 하였습니다. Team3_Data_Seoul_geocoded_all.csv에서 0~7로 서울권역별로 나눔.

seoul0 = pd.read_csv('data/clinic/Team3_Data_Seoul_geocoded_all_0.csv')
seoul1 = pd.read_csv('data/clinic/Team3_Data_Seoul_geocoded_all_1.csv')
seoul2 = pd.read_csv('data/clinic/Team3_Data_Seoul_geocoded_all_2.csv')
seoul3 = pd.read_csv('data/clinic/Team3_Data_Seoul_geocoded_all_3.csv')
seoul4 = pd.read_csv('data/clinic/Team3_Data_Seoul_geocoded_all_4.csv')
seoul5 = pd.read_csv('data/clinic/Team3_Data_Seoul_geocoded_all_5.csv')
seoul6 = pd.read_csv('data/clinic/Team3_Data_Seoul_geocoded_all_6.csv')
seoul7 = pd.read_csv('data/clinic/Team3_Data_Seoul_geocoded_all_7.csv')

seoul0.fillna('', inplace=True)
seoul1.fillna('', inplace=True)
seoul2.fillna('', inplace=True)
seoul3.fillna('', inplace=True)
seoul4.fillna('', inplace=True)
seoul5.fillna('', inplace=True)
seoul6.fillna('', inplace=True)
seoul7.fillna('', inplace=True)

#map = geo.Map(location=[37.509671, 127.05517], zoom_start=11)
map = geo.Map(location=[37.5181205, 126.8865285], zoom_start=10)


for i in range(0, len(seoul0)):
    geo.Marker(
        location = [seoul0.iloc[i]['위도'], seoul0.iloc[i]['경도']],
        popup = '<pre><b>'+seoul0.iloc[i]['의료기관']+'</b></br>'+seoul0.iloc[i]['주소']+'</br>'+seoul0.iloc[i]['상세주소']+'</br>'+str(seoul0.iloc[i]['전화번호'])+'</pre>',
        icon = geo.Icon(color = 'black')
    ).add_to(map)


for i in range(0, len(seoul1)):
    geo.Marker(
        location = [seoul1.iloc[i]['위도'], seoul1.iloc[i]['경도']],
        popup = '<pre><b>'+seoul1.iloc[i]['의료기관']+'</b></br>'+seoul1.iloc[i]['주소']+'</br>'+seoul1.iloc[i]['상세주소']+'</br>'+str(seoul1.iloc[i]['전화번호'])+'</pre>',
        icon = geo.Icon(color = 'red')
    ).add_to(map)
    
for i in range(0, len(seoul2)):
    geo.Marker(
        location = [seoul2.iloc[i]['위도'], seoul2.iloc[i]['경도']],
        popup = '<pre><b>'+seoul2.iloc[i]['의료기관']+'</b></br>'+seoul2.iloc[i]['주소']+'</br>'+seoul2.iloc[i]['상세주소']+'</br>'+str(seoul2.iloc[i]['전화번호'])+'</pre>',
        icon = geo.Icon(color = 'orange')
    ).add_to(map)
    
for i in range(0, len(seoul3)):
    geo.Marker(
        location = [seoul3.iloc[i]['위도'], seoul3.iloc[i]['경도']],
        popup = '<pre><b>'+seoul3.iloc[i]['의료기관']+'</b></br>'+seoul3.iloc[i]['주소']+'</br>'+seoul3.iloc[i]['상세주소']+'</br>'+str(seoul3.iloc[i]['전화번호'])+'</pre>',
        icon = geo.Icon(color = 'beige')
    ).add_to(map)
    
for i in range(0, len(seoul4)):
    geo.Marker(
        location = [seoul4.iloc[i]['위도'], seoul4.iloc[i]['경도']],
        popup = '<pre><b>'+seoul4.iloc[i]['의료기관']+'</b></br>'+seoul4.iloc[i]['주소']+'</br>'+seoul4.iloc[i]['상세주소']+'</br>'+str(seoul4.iloc[i]['전화번호'])+'</pre>',
        icon = geo.Icon(color = 'green')
    ).add_to(map)


for i in range(0, len(seoul5)):
    geo.Marker(
        location = [seoul5.iloc[i]['위도'], seoul5.iloc[i]['경도']],
        popup = '<pre><b>'+seoul5.iloc[i]['의료기관']+'</b></br>'+seoul5.iloc[i]['주소']+'</br>'+seoul5.iloc[i]['상세주소']+'</br>'+str(seoul5.iloc[i]['전화번호'])+'</pre>',
        icon = geo.Icon(color = 'lightblue')
    ).add_to(map)
    
for i in range(0, len(seoul6)):
    geo.Marker(
        location = [seoul6.iloc[i]['위도'], seoul6.iloc[i]['경도']],
        popup = '<pre><b>'+seoul6.iloc[i]['의료기관']+'</b></br>'+seoul6.iloc[i]['주소']+'</br>'+seoul6.iloc[i]['상세주소']+'</br>'+str(seoul6.iloc[i]['전화번호'])+'</pre>',
        icon = geo.Icon(color = 'darkblue')
    ).add_to(map)

for i in range(0, len(seoul7)):
    geo.Marker(
        location = [seoul7.iloc[i]['위도'], seoul7.iloc[i]['경도']],
        popup = '<pre><b>'+seoul7.iloc[i]['의료기관']+'</b></br>'+seoul7.iloc[i]['주소']+'</br>'+seoul7.iloc[i]['상세주소']+'</br>'+str(seoul7.iloc[i]['전화번호'])+'</pre>',
        icon = geo.Icon(color = 'purple')
    ).add_to(map)

    
#지도html파일출력
#map.save('data/clinic/지도_서울_권역별_상담소_참여지원기관.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
